# %%
# Out:
# ...
#   Using cached pyarrow-24.0.0-cp310-cp310-win_amd64.whl.metadata (3.0 kB)
# Using cached pyarrow-24.0.0-cp310-cp310-win_amd64.whl (27.3 MB)
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[2], line 5
#       3 get_ipython().system('{sys.executable} -m pip install pyarrow')
#       4 import pandas as pd
# ----> 5 csi = pd.read_parquet(r"C:\Users\C838122727\Documents\CSU\research\deepkriging_solar\data\processed\residuals\csi_stations.parquet")
#       6 for s in ['S1','S2','S3','P2']:
#       7     over = (csi[s] > 1.0).sum()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
# ...
